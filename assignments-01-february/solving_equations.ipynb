# %%
import pylab as plt

import numpy as np

# %%
f = lambda x: x ** 3 + x - 4

# %%
x = np.linspace(-2, 2)
plt.plot(x, f(x))
plt.axhline(0, color='gray')
plt.show()

# %%
def solve(f, a, b, eps=.01):
    fa = f(a)
    fb = f(b)
    while True:
        m = (a + b) / 2
        fm = f(m)
        
        if abs(fm - 0) < eps:
            return m
        
        if np.sign(fa) == np.sign(fm):
            a, fa = m, fm
        else:
            b, fb = m, fm

# %%
solve(f, -2, 2)
# Out:
# 1.37890625

# %%
g = lambda x: np.exp(x) - x - 2

# %%
x = np.linspace(-4, 2)
plt.plot(x, g(x))
plt.axhline(0, color='gray')
plt.show()

# %%
solve(g, 1, 2)
# Out:
# 1.1484375
