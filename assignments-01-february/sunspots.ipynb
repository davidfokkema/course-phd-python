# %%
import pandas as pd
import pylab as plt

# %%
data = pd.read_table('sunspots.txt', names=['month', 'number'])

# %% [markdown]
# Each column on a pandas DataFrame supports the `rolling` method, which provides rolling window calculations. For example, to calculate a moving average over 10 samples, where the average value is centered on the rolling window:

# %%
data['mean_number'] = data.number.rolling(10, center=True).mean()

# %% [markdown]
# Now, we only have to plot the original data (with a thin line `lw=.5`, and in the background `zorder=1`) with the moving average on top of that (`zorder=2`) with small (`s=1`) red (`c='r'`) dots on the same plot (`ax=ax`).

# %%
ax = data.plot.line('month', 'number', lw=.5, zorder=1)
data.plot.scatter('month', 'mean_number', c='r', s=1, label='mean', ax=ax, zorder=2);
